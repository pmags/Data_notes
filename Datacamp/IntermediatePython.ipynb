# %% [markdown]
# # Intermediate Python
# ## Datacamp Data Analyst Track

# %%
# imports needed libraries
import matplotlib.pyplot as plt

# Creates dataframes
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

# simple plot
plt.plot(year, pop)
plt.show()

# %% [markdown]
# We add `plt.show()` at the end in order to show the plot and because we might want to add some more information as labels before it actually shows.

# %%
# adding a scatter plot
# the S argument on plt.scatter() lets the point size change acording to information
# on a similar fashion c sets colors and alpha sets transperancy
plt.scatter(year,pop)
plt.show()

# %% [markdown]
# With matplotlib, you can create a bunch of different plots in Python. The most basic plot is the line plot. A general recipe is given here.
#
# import matplotlib.pyplot as plt
# plt.plot(x,y)
# plt.show()

# %%
# Print the last item of gdp_cap and life_exp
print(gdp_cap[-1], life_exp[-1])

# Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis
plt.plot(gdp_cap,life_exp)

# Display the plot
plt.show()

# Change the line plot below to a scatter plot
plt.scatter(gdp_cap, life_exp)

# Put the x-axis on a logarithmic scale
plt.xscale("log")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-118c6630fdb5> in <module>
#       1 # Print the last item of gdp_cap and life_exp
# ----> 2 print(gdp_cap[-1], life_exp[-1])
#       3
#       4 # Make a line plot, gdp_cap on the x-axis, life_exp on the y-axis
#       5 plt.plot(gdp_cap,life_exp)
#
# NameError: name 'gdp_cap' is not defined

# %% [markdown]
# In an histogram the height of a bar correspond to the number of data poins **inside each bin.**
#
# To see the documentation of a function one can use
# ```py
#     # documentation on a given function
#     help(plt.hist)
#
#     # cleans plot cach to produce new plos
#     plt.clf()
# ```
#
# we can add more information to our plots using labels
#
# ```py
#     # adds labels to x axis
#     plt.xlabel()
#
#     # adds labels to y axis
#     plt.ylabel()
#
#     # adds title label
#     plt.title()
#
#     # changes y axis intervals and labels
#     plt.yticks([list of intervals], [list of labels])
# ```

# %% [markdown]
# ## Chapter 2 - Dictionaries & Pandas

# %%
# converting population data into a dictionary which connects countries to their own population
pop = [30.55, 2.77, 39.21]
countries = ["afghanistan", "albania", "algeria"]

world = {"afeghanistan":30.55, "albania":2.77,"algeria":39.21}

world["albania"]
# Out:
# 2.77

# %%
# For a dictionary to work correctly as intended, keys should be unique
# We can add information to a dictionary the following way
world["sealand"] = 0.000027
print(world)

"sealand" in world

# in order to delete we use del()
del(world["sealand"])
print(world)
# Out:
# {'afeghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.7e-05}
# {'afeghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %% [markdown]
# The difference between lists and dictionaries is that list are indexed by range of numbers while dictionaries are indexed by unique keys. When we have a collection of data where order matters and we wish to select entire subsets than we should go for lists.

# %%
# it is possible to add multiple data at the same time to a dictionary as the following cde shows
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
europe["france"]["capital"]

# Create sub-dictionary data
data = {"capital":"rome", "population":59.83}

# Add data to europe under key 'italy'
europe["italy"] = data

# Print europe
print(europe)
# Out:
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %%
# to create dataframes in python using pandas we can start from a dictionary
# we can use pd.read_csv(path, index_col=0)
dict = {
    "country":["Brazil", "Russia", "India", "China", "South Africa"],
    "capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "area":[8.516, 17.10, 3.286, 9.597, 1.221],
    "population":[200.4, 143.5, 1252, 1357, 52.98]
}

import pandas as pd
brics = pd.DataFrame(dict)
brics.index = ["BR", "RU", "IN", "CH", "SA"]
print(brics)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-44611fd6a220> in <module>
#       8 }
#       9
# ---> 10 import pandas as pd
#      11 brics = pd.DataFrame(dict)
#      12 brics.index = ["BR", "RU", "IN", "CH", "SA"]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# In a pandas dataframe, if we want to select a column and keep it as a dataframe we will have to use [[]]. Otherwise it returns a panda series
# In order to select only a set of rows we use Loc (label based) or iloc (position based)
# If we want to select all rows but just 2 columns we should set to ":" the first list that appears on brics.loc

brics.loc[["RU"]]
brics.loc[["RU","IN"],["country","capital"]]
brics.loc[:,["country","capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %% [markdown]
# ## Chapter 3 - Logic, Control Flow and Filtering

# %%
z = 4
if z % 2==0 : #then
    print("z is even")

if z % 2 == 0:
    print("z is even")
else :
    print("z is odd")
# Out:
# z is even
# z is even

# %%
z = 3

if z % 2==0 :
    print("z is divisible by 2")
elif z % 3 == 0 :
    print("z is divisible by 3")
else :
    print("z is neither divisible by 2 nor by 3")
# Out:
# z is divisible by 3

# %% [markdown]
# ## Chapter 4 - Loops

# %%
error = 50

while error > 1 :
    error = error / 4
    print(error)
# Out:
# 12.5
# 3.125
# 0.78125

# %% [markdown]
# ```
# for var in seq:
#     expression
# ```

# %% [markdown]
# In order to loop over a Dictionary we use **key, val in mydict.items()** for numpy arrays **for val in np.nditer(my_array)**. Iterating over a Pandas DataFrame is typically done with the iterrows() method. Used in a for loop, every observation is iterated over and on every iteration the row label and actual row contents are available:

# %% [markdown]
# ## Chapter 5 - Case study

# %%
import numpy as np
np.random.seed(123)
coin = np.random.randint(0,2)
print(coin)

if coin == 0:
    print("heads")
else:
    print("tails")
# Out:
# 0
# heads

# %%
# Numpy is imported, seed is set

# Initialization
random_walk = [0]

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7)

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123)
final_tails = []
for x in range(10000) :
    tails = [0]
    for x in range(10) :
        coin = np.random.randint(0,2)
        tails.append(tails[x] + coin)
    final_tails.append(tails[-1])
plt.hist(final_tails, bins = 10)
plt.show()

# %%
all_walks = []
for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)

# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
# numpy and matplotlib imported, seed set

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand()<0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.show()

# %%
# Probablity
len(ends[ends >= 60])/500
# Out:
# 0.788
